# %%
import numpy as np

# %%
social = np.load('../Data/npy/social_Norm15D.npy')
yt_social= social[:,5:]
ig_social = social[:,:5]

# %%
yt_social
# Out:
# array([[9.64467015e-03, 7.27886870e-03, 4.31617204e-03, 2.14304218e-02,
#         2.88174985e-02, 4.26197975e-03, 4.31617204e-03, 1.94822016e-02,
#         2.61977259e-02, 4.26197975e-03],
#        [8.25049871e-05, 2.91289052e-04, 3.39108741e-04, 4.19054005e-05,
#         1.87832752e-04, 1.57152646e-04, 4.06930489e-04, 4.57149823e-05,
#         2.04908456e-04, 1.88583175e-04],
#        [1.34776782e-01, 1.52487544e-01, 1.00000000e+00, 1.21190418e-01,
#         9.16912497e-01, 7.90729251e-01, 1.00000000e+00, 1.10173107e-01,
#         8.33556815e-01, 7.90729251e-01],
#        [8.94473475e-03, 3.10278163e-03, 2.32382922e-03, 1.32002011e-02,
#         1.88959748e-02, 2.99847248e-03, 2.32382922e-03, 1.20001829e-02,
#         1.71781589e-02, 2.99847248e-03],
#        [2.77230666e-01, 4.14090775e-01, 1.33799727e-01, 2.54647690e-01,
#         1.00000000e+00, 8.51024435e-02, 1.47179700e-01, 2.54647690e-01,
#         1.00000000e+00, 9.36126879e-02],
# ...

# %%
np.save('../Data/npy/social_yt10D',yt_social)
np.save('../Data/npy/social_IG5D',ig_social)

# %%
# YouTube (video,text,social)
video = np.load('../Data/npy/Video_512D_6650.npy')
text = np.load('../Data/npy/Text_300D.npy')
yt_feature = np.concatenate((video,text,yt_social),axis=1)
np.save('../Data/npy/YouTuber822D',yt_feature)

# %%
#IG (image,following,social)
image = np.load('../Data/npy/Image_50_2048D.npy')
following = np.load('../Data/npy/Following_64D.npy')
ig_feature = np.concatenate((image,following,ig_social),axis=1)
np.save('../Data/npy/IG2117D',ig_feature)
